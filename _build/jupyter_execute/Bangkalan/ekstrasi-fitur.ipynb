# %% [markdown]
# # Ekstraksi Fitur Deret Waktu Polutan NO₂ Kecamatan Kamal
#
# Melakukan preprocessing dan ekstraksi fitur pada data konsentrasi nitrogen dioksida (NO₂) di Kecamatan Kamal, Kabupaten Bangkalan. Data yang digunakan mencakup periode 31 Agustus 2025 sampai 31 Agustus 2026.
#
# Tahapan pengolahan data yang dilakukan meliputi pengambilan dan pemeriksaan data, deteksi outlier, penanganan outlier, imputasi missing value, validasi data, serta ekstraksi fitur deret waktu menggunakan library TSFEL (Time Series Feature Extraction Library).
#
# ## Pengambilan Data
#
# Data yang digunakan dalam penelitian ini merupakan data konsentrasi polutan **NO₂ (Nitrogen Dioksida)** pada wilayah **Kecamatan Kamal, Kabupaten Bangkalan**. Data diperoleh menggunakan platform **openEO** dengan koleksi data **Sentinel-5P L2** dari Copernicus Data Space Ecosystem (CDSE). Pengambilan data dilakukan secara harian pada rentang waktu **31 Agustus 2025 sampai 31 Agustus 2026**

# %%
pip install openeo
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1.2 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import openeo

connection = openeo.connect("openeo.dataspace.copernicus.eu").authenticate_oidc()
# Out:
# Visit <a href="https://identity.dataspace.copernicus.eu/auth/realms/CDSE/device?user_code=JEFD-CMQC" title="Authenticate at https://identity.dataspace.copernicus.eu/auth/realms/CDSE/device?user_code=JEFD-CMQC" target="_blank" rel="noopener noreferrer">https://identity.dataspace.copernicus.eu/auth/realms/CDSE/device?user_code=JEFD-CMQC</a> <a href="#" onclick="navigator.clipboard.writeText('https://identity.dataspace.copernicus.eu/auth/realms/CDSE/device?user_code=JEFD-CMQC');return false;" title="Copy authentication URL to clipboard">&#128203;</a> to authenticate.
# ❌ Timed out
# ---------------------------------------------------------------------------
# OidcDeviceCodePollTimeout                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 import openeo
#       2
# ----> 3 connection = openeo.connect("openeo.dataspace.copernicus.eu").authenticate_oidc()
#
# ...

# %%
aoi = {
  "type": "FeatureCollection",
  "features": [
    {
      "type": "Feature",
      "properties": {},
      "geometry": {
        "type": "Polygon",
        "coordinates": [
          [
            [
              112.7587724,
              -7.1108073
            ],
            [
              112.6883396,
              -7.1108073
            ],
            [
              112.6883396,
              -7.174627
            ],
            [
              112.7587724,
              -7.174627
            ],
            [
              112.7587724,
              -7.1108073
            ]
          ]
        ]
      }
    }
  ]
}

# %%
s5NO2 = connection.load_collection(
    "SENTINEL_5P_L2",
    temporal_extent=["2025-08-31", "2026-08-31"],
    spatial_extent={
        "west": 112.6883396,
        "south": -7.174627,
        "east": 112.7587724,
        "north": -7.1108073
    },
    bands=["NO2"],
)

# Agregasi harian
s5p_NO2_daily = s5NO2.aggregate_temporal_period(reducer="mean",period="day")

# Agregasi spasial berdasarkan AOI
s5p_NO2_aoi = s5p_NO2_daily.aggregate_spatial(reducer="mean",geometries=aoi)

# Simpan hasil sebagai CSV
result_NO2 = s5p_NO2_aoi.save_result(format="CSV")

# Jalankan job
job_NO2 = result_NO2.create_job(title="s5p_NO2_timeseries")
job_NO2.start_and_wait()

# Download CSV
job_NO2.get_results().download_files("N02_Kamal")
# Out:
# 0:00:00 Job 'j-2609131703024f2c8066068ad29bcd6f': send 'start'
# 0:00:03 Job 'j-2609131703024f2c8066068ad29bcd6f': queued (progress 0%)
# 0:00:08 Job 'j-2609131703024f2c8066068ad29bcd6f': queued (progress 0%)
# 0:00:15 Job 'j-2609131703024f2c8066068ad29bcd6f': queued (progress 0%)
# 0:00:23 Job 'j-2609131703024f2c8066068ad29bcd6f': queued (progress 0%)
# 0:00:33 Job 'j-2609131703024f2c8066068ad29bcd6f': queued (progress 0%)
# 0:00:45 Job 'j-2609131703024f2c8066068ad29bcd6f': queued (progress 0%)
# 0:01:01 Job 'j-2609131703024f2c8066068ad29bcd6f': queued (progress 0%)
# 0:01:20 Job 'j-2609131703024f2c8066068ad29bcd6f': running (progress N/A)
# 0:01:44 Job 'j-2609131703024f2c8066068ad29bcd6f': running (progress N/A)
# 0:02:14 Job 'j-2609131703024f2c8066068ad29bcd6f': running (progress N/A)
# 0:02:51 Job 'j-2609131703024f2c8066068ad29bcd6f': running (progress N/A)
# 0:04:36 Job 'j-2609131703024f2c8066068ad29bcd6f': finished (progress 100%)
# [PosixPath('N02_Kamal/timeseries.csv'),
# ...

# %%
# !pip install matplotlib
# !pip install tsfel
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.4/63.4 kB 2.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 40.0 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.3/9.3 MB 75.2 MB/s eta 0:00:00:00:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.3/35.3 MB 47.9 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 87.2 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 306.1/306.1 kB 40.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 474.0/474.0 kB 45.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.3/233.3 kB 38.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.9/118.9 kB 19.3 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## Deteksi Outlier
#
# Deteksi outlier dilakukan untuk mengidentifikasi nilai NO₂ yang memiliki penyimpangan cukup jauh dari distribusi data. Metode yang digunakan adalah **Interquartile Range (IQR)**.
#
# Nilai outlier ditentukan berdasarkan batas bawah dan batas atas:
#
# * **Q1** = kuartil pertama (25%)
# * **Q3** = kuartil ketiga (75%)
# * **IQR** = Q3 − Q1
# * **Batas bawah** = Q1 − 1,5 × IQR
# * **Batas atas** = Q3 + 1,5 × IQR
#
# Data yang memiliki nilai NO₂ di bawah batas bawah atau di atas batas atas dikategorikan sebagai outlier.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv("mystorage/N02_Kamal/timeseries.csv")
df['date'] = pd.to_datetime(df['date'])
df = df.sort_values('date').reset_index(drop=True)

# Hitung IQR
Q1 = df['NO2'].quantile(0.25)
Q3 = df['NO2'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Filter outlier
outliers_iqr = df[(df['NO2'] < lower_bound) | (df['NO2'] > upper_bound)]

print("Jumlah Outlier (IQR):", len(outliers_iqr))
print(outliers_iqr[['date', 'NO2']].head())
# Out:
# Jumlah Outlier (IQR): 11
#                          date       NO2
# 24  2025-09-23 00:00:00+00:00  0.000114
# 39  2025-10-08 00:00:00+00:00  0.000094
# 88  2025-11-26 00:00:00+00:00  0.000094
# 104 2025-12-12 00:00:00+00:00  0.000110
# 121 2025-12-29 00:00:00+00:00  0.000096

# %% [markdown]
# Berdasarkan metode IQR, nilai yang berada di luar batas bawah dan batas atas diidentifikasi sebagai outlier. Hasil deteksi ditampilkan untuk mengetahui tanggal dan nilai NO₂ yang terindikasi sebagai outlier sebelum dilakukan penanganan.
#
# ## Penanganan Outlier dan Missing Value
#
# Outlier yang telah teridentifikasi tidak langsung dihapus dari dataset. Nilai tersebut terlebih dahulu ditandai sebagai **NaN** agar jumlah observasi tetap dipertahankan. Selanjutnya dilakukan proses imputasi untuk mengisi nilai yang kosong. Metode **interpolasi linier** digunakan untuk memperkirakan nilai berdasarkan data di sekitarnya. Apabila masih terdapat nilai kosong pada bagian awal atau akhir deret waktu, nilai tersebut diisi menggunakan metode **backward fill (bfill)** dan **forward fill (ffill)**. Dengan proses tersebut, data diharapkan tidak lagi memiliki missing value dan dapat digunakan pada tahap ekstraksi fitur.

# %%
# Tandai outlier menjadi NaN
df['NO2_cleaned'] = df['NO2'].mask(
    (df['NO2'] < lower_bound) | (df['NO2'] > upper_bound)
)

# Lakukan interpolasi linier pada NaN yang sudah dibuat
df['NO2_filled'] = df['NO2_cleaned'].interpolate(method='linear')

# Jika masih ada NaN di bagian awal/akhir, isi dengan nilai terdekat
df['NO2_filled'] = df['NO2_filled'].bfill().ffill()

# Buat dataframe hasil akhir
df_no2_kamal = pd.DataFrame({
    "date": df['date'],
    "NO2": df['NO2_filled']
})

# Simpan ke CSV
df_no2_kamal.to_csv("mystorage/N02_Kamal/NO2_Kamal_filled.csv", index=False)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv("mystorage/N02_Kamal/NO2_Kamal_filled.csv")
df['date'] = pd.to_datetime(df['date'])
df = df.sort_values('date').reset_index(drop=True)

# Hitung IQR
Q1 = df['NO2'].quantile(0.25)
Q3 = df['NO2'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Filter outlier
outliers_iqr = df[(df['NO2'] < lower_bound) | (df['NO2'] > upper_bound)]

print("Jumlah Outlier (IQR):", len(outliers_iqr))
print(outliers_iqr[['date', 'NO2']].head())
# Out:
# Jumlah Outlier (IQR): 0
# Empty DataFrame
# Columns: [date, NO2]
# Index: []

# %% [markdown]
# ## Ekstraksi Fitur Deret Waktu Menggunakan TSFEL
#
# Setelah data dinyatakan bersih, dilakukan ekstraksi fitur menggunakan **TSFEL (Time Series Feature Extraction Library)**.
#
# Ekstraksi dilakukan terhadap deret waktu polutan **NO₂ Kecamatan Kamal**. Sebanyak **68 fitur** diekstraksi dari data yang telah melalui tahap preprocessing.
#
# Fitur yang dihasilkan mencakup beberapa karakteristik deret waktu, antara lain fitur pada domain **Statistical, Temporal, dan Spectral**. Hasil ekstraksi kemudian disimpan dalam bentuk file CSV untuk digunakan pada tahap selanjutnya.

# %%
import pandas as pd
import numpy as np
import inspect
import tsfel.feature_extraction.features as tsfel_features

# ---------- 1. Muat data yang sudah dibersihkan ----------
df = pd.read_csv('mystorage/N02_Kamal/NO2_Kamal_filled.csv')
df['date'] = pd.to_datetime(df['date'])
df = df.sort_values('date').reset_index(drop=True)

target_pollutant = 'NO2'

# Pastikan data di-casting ke tipe numerik.
df[target_pollutant] = pd.to_numeric(df[target_pollutant], errors='coerce')

# Interpolasi terakhir untuk berjaga-jaga apabila terdapat sisa format nan
df_clean = df.set_index('date').interpolate(method='time').ffill().bfill()
fs = 1
signal_1d = df_clean[target_pollutant].astype(float).values

# ---------- 2. Inisiasi 68 Daftar Fitur TSFEL ----------
FEATURE_LIST = """abs_energy auc autocorr average_power calc_centroid calc_max calc_mean
calc_median calc_min calc_std calc_var dfa distance ecdf ecdf_percentile ecdf_percentile_count
ecdf_slope entropy fundamental_frequency higuchi_fractal_dimension hist_mode human_range_energy
hurst_exponent interq_range kurtosis lempel_ziv lpcc max_frequency max_power_spectrum
maximum_fractal_length mean_abs_deviation mean_abs_diff mean_diff median_abs_deviation
median_abs_diff median_diff median_frequency mfcc mse negative_turning neighbourhood_peaks
petrosian_fractal_dimension pk_pk_distance positive_turning power_bandwidth rms skewness slope
spectral_centroid spectral_decrease spectral_distance spectral_entropy spectral_kurtosis
spectral_positive_turning spectral_roll_off spectral_roll_on spectral_skewness spectral_slope
spectral_spread spectral_variation spectrogram_mean_coeff sum_abs_diff wavelet_abs_mean
wavelet_energy wavelet_entropy wavelet_std wavelet_var zero_cross""".split()

print("Jumlah fitur yang diminta:", len(FEATURE_LIST))

# ---------- 3. Fungsi ekstraksi dan penyeragaman output  ----------

# Fungsi bantuan (helper) merubah output multivariat TSFEL menjadi float tunggal/skalar
def to_scalar(result):
    if isinstance(result, dict) and "values" in result:
        result = result["values"]
    if isinstance(result, (list, tuple, np.ndarray)):
        arr = np.asarray(result, dtype=float)
        return float(np.nanmean(arr))
    return float(result)

# Fungsi map pemanggilan fungsi TSFEL 
def extract_one(fn_name, signal, fs):
    fn = getattr(tsfel_features, fn_name)
    params = inspect.signature(fn).parameters
    if "fs" in params:
        result = fn(signal, fs)
    else:
        result = fn(signal)
    return to_scalar(result)

# Lakukan ekstraksi iteratif pada fitur
row = {}
for fn_name in FEATURE_LIST:
    row[fn_name] = extract_one(fn_name, signal_1d, fs)

extracted_features_final = pd.DataFrame([row])

print(f"Berhasil! Jumlah fitur yang diekstrak pada {target_pollutant}: {extracted_features_final.shape[1]}")

# Export hasil ke file CSV
extracted_features_final.to_csv(f'mystorage/N02_Kamal{target_pollutant}_Kamal_TSFEL.csv', index=False)
# Out:
# Jumlah fitur yang diminta: 68
# Berhasil! Jumlah fitur yang diekstrak pada NO2: 68

# %% [markdown]
# ## Hasil Ekstraksi Fitur
#
# Hasil ekstraksi menghasilkan **68 fitur TSFEL** yang merepresentasikan karakteristik deret waktu polutan NO₂.
#
# Setiap fitur memberikan informasi yang berbeda mengenai pola dan karakteristik data. Fitur-fitur tersebut kemudian disimpan ke dalam file CSV sebagai hasil akhir dari proses ekstraksi fitur.

# %%
df = pd.read_csv("mystorage/N02_KamalNO2_Kamal_TSFEL.csv")
df.head(5)
# Out:
#      abs_energy       auc  autocorr  average_power  calc_centroid  calc_max  \
# 0  7.363589e-07  0.015059      11.0   2.017422e-09     166.039562  0.000086
#
#    calc_mean  calc_median      calc_min  calc_std  ...  spectral_spread  \
# 0   0.000041     0.000041 -6.819737e-07  0.000018  ...         0.144113
#
#    spectral_variation  spectrogram_mean_coeff  sum_abs_diff  wavelet_abs_mean  \
# 0            0.282633            4.347435e-10      0.002744          0.000001
#
#    wavelet_energy  wavelet_entropy  wavelet_std   wavelet_var  zero_cross
# 0        0.000023         2.131037     0.000023  6.029033e-10         2.0
#
# [1 rows x 68 columns]

# %% [markdown]
# ## Pengelompokan dan Penjelasan Fitur TSFEL
#
# Setelah data NO₂ dinyatakan bersih dari outlier dan missing value, dilakukan ekstraksi fitur menggunakan library **TSFEL (Time Series Feature Extraction Library)**. Pada penelitian ini digunakan sebanyak **68 fitur** untuk menggambarkan berbagai karakteristik deret waktu konsentrasi NO₂.
#
# Fitur-fitur tersebut dikelompokkan ke dalam tiga domain utama, yaitu **Statistical, Temporal, dan Spectral**.
#
# ### 1. Statistical Domain
#
# Statistical Domain berisi fitur yang menggambarkan karakteristik statistik, distribusi, penyebaran, perubahan nilai, serta energi dari data deret waktu.
#
# 1. **abs_energy** — mengukur total energi atau besarnya nilai sinyal berdasarkan kuadrat nilai-nilainya.
# 2. **auc** — menghitung luas area di bawah kurva deret waktu.
# 3. **average_power** — mengukur rata-rata daya atau energi sinyal.
# 4. **calc_max** — menentukan nilai maksimum dalam deret waktu.
# 5. **calc_mean** — menghitung nilai rata-rata.
# 6. **calc_median** — menentukan nilai tengah atau median.
# 7. **calc_min** — menentukan nilai minimum.
# 8. **calc_std** — menghitung standar deviasi untuk mengetahui tingkat penyebaran data.
# 9. **calc_var** — menghitung varians data.
# 10. **ecdf** — menghasilkan karakteristik distribusi kumulatif empiris dari data.
# 11. **ecdf_percentile** — menentukan persentil berdasarkan distribusi kumulatif empiris.
# 12. **ecdf_percentile_count** — menghitung jumlah data berdasarkan persentil tertentu.
# 13. **ecdf_slope** — menggambarkan perubahan atau kemiringan distribusi kumulatif empiris.
# 14. **entropy** — mengukur tingkat ketidakpastian atau kompleksitas distribusi nilai.
# 15. **hist_mode** — menentukan modus atau nilai yang paling dominan berdasarkan histogram.
# 16. **human_range_energy** — mengukur energi sinyal pada rentang tertentu yang berkaitan dengan rentang pengamatan manusia.
# 17. **interq_range** — menghitung rentang interkuartil atau selisih antara Q3 dan Q1.
# 18. **kurtosis** — menggambarkan tingkat keruncingan distribusi data.
# 19. **mean_abs_deviation** — menghitung rata-rata penyimpangan absolut terhadap nilai pusat.
# 20. **mean_abs_diff** — menghitung rata-rata selisih absolut antar nilai berurutan.
# 21. **mean_diff** — menghitung rata-rata perubahan atau selisih antar nilai.
# 22. **median_abs_deviation** — mengukur penyimpangan absolut median.
# 23. **median_abs_diff** — menghitung median dari selisih absolut antar nilai berurutan.
# 24. **median_diff** — menghitung median perubahan antar nilai berurutan.
# 25. **mse** — menghitung mean squared error atau rata-rata kuadrat kesalahan/perbedaan.
# 26. **pk_pk_distance** — mengukur jarak antara nilai puncak maksimum dan minimum.
# 27. **rms** — menghitung root mean square sebagai ukuran besarnya sinyal.
# 28. **skewness** — menggambarkan kemencengan distribusi data.
# 29. **slope** — mengukur kecenderungan naik atau turun pada deret waktu.
# 30. **sum_abs_diff** — menghitung jumlah seluruh selisih absolut antar nilai berurutan.
#
# ### 2. Temporal Domain
#
# Temporal Domain berfokus pada pola perubahan data berdasarkan urutan waktu, hubungan antarobservasi, kompleksitas, serta karakteristik struktur temporal pada deret waktu.
#
# 31. **autocorr** — mengukur korelasi antara nilai deret waktu dengan nilai sebelumnya pada lag tertentu.
# 32. **dfa** — digunakan untuk menganalisis korelasi jangka panjang dan karakteristik fluktuasi pada deret waktu.
# 33. **distance** — mengukur karakteristik jarak atau perubahan sepanjang deret waktu.
# 34. **hurst_exponent** — menggambarkan kecenderungan deret waktu untuk mempertahankan atau membalik pola perubahan sebelumnya.
# 35. **lempel_ziv** — mengukur kompleksitas deret waktu berdasarkan pola atau urutan yang muncul.
# 36. **maximum_fractal_length** — mengukur panjang fraktal maksimum yang terbentuk dari deret waktu.
# 37. **neighbourhood_peaks** — mengidentifikasi karakteristik puncak lokal berdasarkan lingkungan atau titik di sekitarnya.
# 38. **negative_turning** — menghitung karakteristik titik perubahan arah ke arah negatif.
# 39. **positive_turning** — menghitung karakteristik titik perubahan arah ke arah positif.
# 40. **zero_cross** — menghitung jumlah atau karakteristik perpotongan sinyal terhadap nilai nol.
# 41. **calc_centroid** — menentukan pusat massa atau titik pusat distribusi sinyal.
# 42. **maximum_fractal_length** — menggambarkan karakteristik panjang maksimum struktur fraktal pada sinyal.
#
# ### 3. Spectral Domain
#
# Spectral Domain menganalisis karakteristik data berdasarkan frekuensi. Domain ini digunakan untuk mengetahui distribusi energi, komponen frekuensi, serta karakteristik spektrum dari deret waktu NO₂.
#
# 43. **fundamental_frequency** — menentukan frekuensi dasar atau frekuensi utama dari sinyal.
# 44. **max_frequency** — menentukan frekuensi dengan nilai atau kontribusi maksimum.
# 45. **max_power_spectrum** — menentukan nilai daya maksimum pada spektrum frekuensi.
# 46. **median_frequency** — menentukan frekuensi median berdasarkan distribusi energi spektrum.
# 47. **power_bandwidth** — mengukur lebar rentang frekuensi yang membawa energi tertentu.
# 48. **spectral_centroid** — menentukan pusat distribusi energi pada spektrum frekuensi.
# 49. **spectral_decrease** — mengukur tingkat penurunan energi spektrum terhadap frekuensi.
# 50. **spectral_distance** — mengukur jarak atau perubahan karakteristik antarbagian spektrum.
# 51. **spectral_entropy** — mengukur tingkat ketidakpastian atau penyebaran energi pada spektrum.
# 52. **spectral_kurtosis** — menggambarkan keruncingan distribusi energi pada spektrum.
# 53. **spectral_positive_turning** — mengidentifikasi karakteristik perubahan arah positif pada spektrum.
# 54. **spectral_roll_off** — menentukan frekuensi batas tempat sebagian besar energi spektrum berada di bawahnya.
# 55. **spectral_roll_on** — menentukan frekuensi awal dari rentang energi spektrum.
# 56. **spectral_skewness** — menggambarkan kemencengan distribusi energi pada spektrum.
# 57. **spectral_slope** — mengukur kemiringan perubahan energi terhadap frekuensi.
# 58. **spectral_spread** — mengukur penyebaran energi di sekitar spectral centroid.
# 59. **spectral_variation** — mengukur perubahan karakteristik spektrum.
# 60. **spectrogram_mean_coeff** — menghitung karakteristik rata-rata koefisien pada spectrogram.
# 61. **wavelet_abs_mean** — menghitung rata-rata nilai absolut koefisien wavelet.
# 62. **wavelet_energy** — mengukur energi yang terdapat pada representasi wavelet.
# 63. **wavelet_entropy** — mengukur kompleksitas atau ketidakpastian distribusi energi pada koefisien wavelet.
# 64. **wavelet_std** — menghitung standar deviasi koefisien wavelet.
# 65. **wavelet_var** — menghitung varians koefisien wavelet.
# 66. **lpcc** — mengekstraksi karakteristik sinyal menggunakan Linear Predictive Cepstral Coefficients.
# 67. **mfcc** — mengekstraksi karakteristik sinyal menggunakan Mel-Frequency Cepstral Coefficients.
# 68. **higuchi_fractal_dimension** dan **petrosian_fractal_dimension** — mengukur kompleksitas atau dimensi fraktal dari deret waktu.
#
# ### Ringkasan
#
# Secara keseluruhan, terdapat **68 fitur TSFEL** yang digunakan untuk menganalisis karakteristik deret waktu NO₂. Ketiga domain tersebut memberikan sudut pandang yang berbeda:
#
# * **Statistical** → menggambarkan nilai, distribusi, penyebaran, dan perubahan statistik data.
# * **Temporal** → menggambarkan pola, hubungan antarwaktu, kompleksitas, dan perubahan arah deret waktu.
# * **Spectral** → menggambarkan karakteristik frekuensi, distribusi energi, spektrum, serta representasi wavelet.
#
# Hasil ekstraksi 68 fitur kemudian disimpan dalam file CSV dan digunakan sebagai data masukan untuk tahap penyimpanan ke database Aiven.
